# %%
import pandas as pd
import numpy as np

df = pd.read_csv("/content/sleepDay_merged.csv")

df.head()
# Out:
#            Id               SleepDay  TotalSleepRecords  TotalMinutesAsleep  \
# 0  1503960366  4/12/2016 12:00:00 AM                  1                 327
# 1  1503960366  4/13/2016 12:00:00 AM                  2                 384
# 2  1503960366  4/15/2016 12:00:00 AM                  1                 412
# 3  1503960366  4/16/2016 12:00:00 AM                  2                 340
# 4  1503960366  4/17/2016 12:00:00 AM                  1                 700
#
#    TotalTimeInBed
# 0             346
# 1             407
# 2             442
# 3             367
# 4             712

# %%
df.tail()
# Out:
#              Id               SleepDay  TotalSleepRecords  TotalMinutesAsleep  \
# 408  8792009665  4/30/2016 12:00:00 AM                  1                 343
# 409  8792009665   5/1/2016 12:00:00 AM                  1                 503
# 410  8792009665   5/2/2016 12:00:00 AM                  1                 415
# 411  8792009665   5/3/2016 12:00:00 AM                  1                 516
# 412  8792009665   5/4/2016 12:00:00 AM                  1                 439
#
#      TotalTimeInBed
# 408             360
# 409             527
# 410             423
# 411             545
# 412             463

# %%
df.shape
# Out:
# (413, 5)

# %%
df.describe()
# Out:
#                  Id  TotalSleepRecords  TotalMinutesAsleep  TotalTimeInBed
# count  4.130000e+02         413.000000          413.000000      413.000000
# mean   5.000979e+09           1.118644          419.467312      458.639225
# std    2.060360e+09           0.345521          118.344679      127.101607
# min    1.503960e+09           1.000000           58.000000       61.000000
# 25%    3.977334e+09           1.000000          361.000000      403.000000
# 50%    4.702922e+09           1.000000          433.000000      463.000000
# 75%    6.962181e+09           1.000000          490.000000      526.000000
# max    8.792010e+09           3.000000          796.000000      961.000000

# %%
df.columns
# Out:
# Index(['Id', 'SleepDay', 'TotalSleepRecords', 'TotalMinutesAsleep',
#        'TotalTimeInBed'],
#       dtype='object')

# %%
#changing all the proper camel-case names to lowercase
df.rename({'Id': 'ID', 'SleepDay': 'sleep day', 'TotalSleepRecords': 'total sleep records',
           'TotalMinutesAsleep': 'total minutes asleep', 'TotalTimeInBed': 'total time in bed'}, axis=1, inplace=True)

df.columns
# Out:
# Index(['ID', 'sleep day', 'total sleep records', 'total minutes asleep',
#        'total time in bed'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 413 entries, 0 to 412
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    413 non-null    int64
#  1   sleep day             413 non-null    object
#  2   total sleep records   413 non-null    int64
#  3   total minutes asleep  413 non-null    int64
#  4   total time in bed     413 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 16.3+ KB

# %%
#convert "sleep day" column to datetime data type
df['sleep day'] = pd.to_datetime(df['sleep day'])

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 413 entries, 0 to 412
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    413 non-null    int64
#  1   sleep day             413 non-null    datetime64[ns]
#  2   total sleep records   413 non-null    int64
#  3   total minutes asleep  413 non-null    int64
#  4   total time in bed     413 non-null    int64
# dtypes: datetime64[ns](1), int64(4)
# memory usage: 16.3 KB

# %%
df.nunique()
# Out:
# ID                       24
# sleep day                31
# total sleep records       3
# total minutes asleep    256
# total time in bed       242
# dtype: int64

# %%
df.isnull().sum()
# Out:
# ID                      0
# sleep day               0
# total sleep records     0
# total minutes asleep    0
# total time in bed       0
# dtype: int64

# %% [markdown]
# **DATA VISUALISATION**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(x='sleep day', data=df, )
plt.show()

# %%
#scatterplot with total minute asleep against time in bed
plt.plot(df['total minutes asleep'])
plt.plot(df['time in bed'])

plt.title("Scatter Plot")

plt.xlabel('total minutes asleep')
plt.ylabel('time in bed')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'time in bed'
#
# The above exception was the direct cause of the following exception:
#
# ...
